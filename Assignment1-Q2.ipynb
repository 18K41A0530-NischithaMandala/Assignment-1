# %%
print("enter distance to be travelled",end=" ")
distance=int(input())
print("enter weight of goods",end=" ")
weight=int(input())
if(distance>=500):
    if(weight>=100):
        c=5
    elif(weight>=10 and weight<100):
        c=6
    else:
        c=7
else:
    if(weight>=100):
        c=8
    else:
        c=5
print(f'amount to be charged : {distance*c}')
# Out:
# enter distance to be travelled 520
# enter weight of goods 50
# amount to be charged : 3120
